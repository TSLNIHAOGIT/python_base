# %%
import urllib.parse
values={}
values['username']='02蔡彩虹'
values['password']='ddddd?'
url="http://www.baidu.com"
data=urllib.parse.urlencode(values)
print(data)
# Out:
# username=02%E8%94%A1%E5%BD%A9%E8%99%B9&password=ddddd%3F

# %%
values
# Out:
# {'username': '02蔡彩虹', 'password': 'ddddd?'}

# %%
from urllib import parse
from urllib import request

url = 'http://www.baidu.com/s?'
dict1 ={'wd': '百度翻译'}
url_data = parse.urlencode(dict1) #unlencode()将字典{k1:v1,k2:v2}转化为k1=v1&k2=v2
print(url_data)             #url_data：wd=%E7%99%BE%E5%BA%A6%E7%BF%BB%E8%AF%91
data = request.urlopen((url+url_data)).read() #读取url响应结果
data = data.decode('utf-8') #将响应结果用utf8编码
print(data)
url_org = parse.unquote(url_data) #解码url
print(url_org)              #url_org：wd=百度翻译
str1 = 'haha哈哈'
str2 = parse.quote(str1)    #将字符串进行编码
print(str2)                 #str2=haha%E5%93%88%E5%93%88
str3 = parse.unquote(str2)  #解码字符串
print(str3)                 #str3=haha哈哈
# Out:
# wd=%E7%99%BE%E5%BA%A6%E7%BF%BB%E8%AF%91
# <!DOCTYPE html>
# <!--STATUS OK-->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <html>
# 	<head>
#
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 		<meta http-equiv="content-type" content="text/html;charset=utf-8">
# 		<meta content="always" name="referrer">
#         <meta name="theme-color" content="#2932e1">
#         <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
#         <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg">
#         <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="百度搜索" />
#
#
# <title>百度翻译_百度搜索</title>
#
#
#
#
# <style data-for="result" type="text/css" id="css_newi_result">body{color:#333;background:#fff;padding:6px 0 0;margin:0;position:relative}
# ...

# %%
str1 = 'haha哈哈'
str2 = parse.quote(str1)   #quote()将字符串进行编码
print(str2)                #str2=haha%E5%93%88%E5%93%88
str3 = parse.unquote(str2) #解码字符串
print(str3)                #str3=haha哈哈
# Out:
# haha%E5%93%88%E5%93%88
# haha哈哈

# %%
chrome_url='''https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512%C2%A0%E6%99%82%E4%BB%A3(%E8%8B%B1%E5%BE%B3)chk%C2%A026%E8%99%9F%E6%9F%9C515%E4%BB%B6%E5%A0%B1%E9%97%9C%E8%B3%87%E6%96%99%EF%BC%88%E4%B8%80%E8%88%AC%E8%B4%B8%E6%98%93%EF%BC%89%CE%A9%E6%8A%A5%E5%85%B3%E5%8D%95-4.xlsx'''

# %%
url='''https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512%20%E6%99%82%E4%BB%A3%28%E8%8B%B1%E5%BE%B3%29chk%2026%E8%99%9F%E6%9F%9C515%E4%BB%B6%E5%A0%B1%E9%97%9C%E8%B3%87%E6%96%99%EF%BC%88%E4%B8%80%E8%88%AC%E8%B4%B8%E6%98%93%EF%BC%89%CE%A9%E6%8A%A5%E5%85%B3%E5%8D%95-4.xlsx'''

# %%
parse.unquote(url)
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-4.xlsx'

# %%
ddd=parse.unquote(chrome_url)

# %%
ddd
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512\xa0時代(英徳)chk\xa026號柜515件報關資料（一般贸易）Ω报关单-4.xlsx'

# %%
parse.quote(ddd, encoding='utf8', safe='/:?=& ')
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512%C2%A0%E6%99%82%E4%BB%A3%28%E8%8B%B1%E5%BE%B3%29chk%C2%A026%E8%99%9F%E6%9F%9C515%E4%BB%B6%E5%A0%B1%E9%97%9C%E8%B3%87%E6%96%99%EF%BC%88%E4%B8%80%E8%88%AC%E8%B4%B8%E6%98%93%EF%BC%89%CE%A9%E6%8A%A5%E5%85%B3%E5%8D%95-4.xlsx'

# %%
data={"account_id": "34501391836729344", "app_name": "dec", "batch_size": "", "callback": "http://121.36.68.168:18201/api/customs/dec/recognition/callback", "company_name": "zph", "customs_broker_id": "34501391413104640", "debug": "0", "declare_type": "dec", "in_out_type": "E", "ocr_data_dir": "", "ocr_data_files": {"other_file": [{"id": "a99cf723-5984-4c21-9e7d-f232560aa589", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-4.xlsx", "type": "single_grass"}, {"id": "15663574-4df8-4493-ab48-47b4a60103e4", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω申报要素.xlsx", "type": "single_grass"}, {"id": "6d7fa6a7-840a-42c7-b5bd-aa862287ab54", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω7.77版更新内容.xlsx", "type": "single_grass"}, {"id": "8ff16738-befc-4809-83bc-0f6b1f491cff", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω装箱明细.xlsx", "type": "single_grass"}, {"id": "e71697df-dd2e-41d3-b2ce-e634077fb062", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω装箱单.xlsx", "type": "single_grass"}, {"id": "c9a18a85-d555-448a-925d-5441695b3051", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω合同.xlsx", "type": "single_grass"}, {"id": "e2cf058d-9553-4937-9254-599b7def9801", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω发票.xlsx", "type": "single_grass"}, {"id": "d444a9a4-d953-4a17-8ef3-3a22e542ec68", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单2.xlsx", "type": "single_grass"}, {"id": "d83b9268-6a6d-48b1-a63d-12f870541f7d", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单1.xlsx", "type": "single_grass"}, {"id": "82673028-dd7f-4501-b692-6915a4e4fcc0", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）ΩASN.xlsx", "type": "single_grass"}, {"id": "5ddfec5a-953e-4ff9-a792-4931ca295d1e", "path": "https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-3.xlsx", "type": "single_grass"}], "pdf_file": []}, "output_type": "path", "overseas_consignor_en_name": "", "parallel": "1", "path": "/uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235", "project_id": "34501391413104640", "provider": "", "sync": "0", "template_id": "", "ticket": "BG20210722152755558235", "token": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..K7Vaad-TPNjrJxWlrUNCqivZGETttbOghdxbN8qlp9DFjk4506oLntvtB9dCIX16kCLH7VAeg9RESYznqbxvSXF-u4Ly5q06ftCkO3pxQHfRfIYeyCmwP6qOVC1fwWlqcJBjXO59O4VoORSuGidUzzosa9sinUE2uk4bzcuRxto", "trnId": "", "trn_flag": "", "trn_template_id": ""}

# %%
raw_url='''https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-4.xlsx'''
raw_url
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-4.xlsx'

# %%
rr_url=raw_url.replace(' ','\xa0')
rr_url
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512\xa0時代(英徳)chk\xa026號柜515件報關資料（一般贸易）Ω报关单-4.xlsx'

# %%
parse.quote(rr_url, encoding='utf8', safe='/:?=& ')
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512%C2%A0%E6%99%82%E4%BB%A3%28%E8%8B%B1%E5%BE%B3%29chk%C2%A026%E8%99%9F%E6%9F%9C515%E4%BB%B6%E5%A0%B1%E9%97%9C%E8%B3%87%E6%96%99%EF%BC%88%E4%B8%80%E8%88%AC%E8%B4%B8%E6%98%93%EF%BC%89%CE%A9%E6%8A%A5%E5%85%B3%E5%8D%95-4.xlsx'

# %%
# help(parse.quote)

# %%
# raw_url= raw_url.encode("utf-8")
raw_parse_url=parse.quote(raw_url, encoding='utf8', safe='/:?=&()')
raw_parse_url
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512%20%E6%99%82%E4%BB%A3(%E8%8B%B1%E5%BE%B3)chk%2026%E8%99%9F%E6%9F%9C515%E4%BB%B6%E5%A0%B1%E9%97%9C%E8%B3%87%E6%96%99%EF%BC%88%E4%B8%80%E8%88%AC%E8%B4%B8%E6%98%93%EF%BC%89%CE%A9%E6%8A%A5%E5%85%B3%E5%8D%95-4.xlsx'

# %%
raw_parse_url.replace('%20','%C2%A0')

# %%
parse.unquote('%C2%A0')
# Out:
# '\xa0'

# %%
chrome_url
# Out:
# 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512%C2%A0%E6%99%82%E4%BB%A3(%E8%8B%B1%E5%BE%B3)chk%C2%A026%E8%99%9F%E6%9F%9C515%E4%BB%B6%E5%A0%B1%E9%97%9C%E8%B3%87%E6%96%99%EF%BC%88%E4%B8%80%E8%88%AC%E8%B4%B8%E6%98%93%EF%BC%89%CE%A9%E6%8A%A5%E5%85%B3%E5%8D%95-4.xlsx'

# %%
dd=''' https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-4.xlsx'''

# %%
dd
# Out:
# ' https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-4.xlsx'

# %%
data
# Out:
# {'account_id': '34501391836729344',
#  'app_name': 'dec',
#  'batch_size': '',
#  'callback': 'http://121.36.68.168:18201/api/customs/dec/recognition/callback',
#  'company_name': 'zph',
#  'customs_broker_id': '34501391413104640',
#  'debug': '0',
#  'declare_type': 'dec',
#  'in_out_type': 'E',
#  'ocr_data_dir': '',
#  'ocr_data_files': {'other_file': [{'id': 'a99cf723-5984-4c21-9e7d-f232560aa589',
#     'path': 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω报关单-4.xlsx',
#     'type': 'single_grass'},
#    {'id': '15663574-4df8-4493-ab48-47b4a60103e4',
#     'path': 'https://robot.superlucy.net/api/customs/core/storage/preview?id=uploads/amiintellect-customs/dec/2021/3Q/7/34501391413104640/zph/BG20210722152755558235/single_grass/ick21070512 時代(英徳)chk 26號柜515件報關資料（一般贸易）Ω申报要素.xlsx',
#     'type': 'single_grass'},
# ...
